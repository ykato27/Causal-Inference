# %% [markdown]
# <table border="0">
#     <tr>
#         <td>
#             <img src="https://ictd2016.files.wordpress.com/2016/04/microsoft-research-logo-copy.jpg" style="width 30px;" />
#              </td>
#         <td>
#             <img src="https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/MSR-ALICE-HeaderGraphic-1920x720_1-800x550.jpg" style="width 100px;"/></td>
#         </tr>
# </table>

# %% [markdown]
# # Orthogonal Random Forest and Causal Forest: Use Cases and Examples
#
# Causal Forests and Generalized Random Forests are a flexible method for estimating treatment effect heterogeneity with Random Forests. Orthogonal Random Forest (ORF) combines orthogonalization, a technique that effectively removes the confounding effect in two-stage estimation, with generalized random forests. Due to the orthogonalization aspect of this method, the ORF performs especially well in the presence of high-dimensional confounders. For more details, see [this paper](https://arxiv.org/abs/1806.03467) or the [EconML docummentation](https://econml.azurewebsites.net/).
#
# The EconML SDK implements the following OrthoForest variants:
#
# * DMLOrthoForest: suitable for continuous or discrete treatments
#
# * DROrthoForest: suitable for discrete treatments
#
# * CausalForest: suitable for both discrete and continuous treatments
#
# In this notebook, we show the performance of the ORF on synthetic and observational data.
#
# ## Notebook Contents
#
# 1. [Example Usage with Continuous Treatment Synthetic Data](#1.-Example-Usage-with-Continuous-Treatment-Synthetic-Data)
# 2. [Example Usage with Binary Treatment Synthetic Data](#2.-Example-Usage-with-Binary-Treatment-Synthetic-Data)
# 3. [Example Usage with Multiple Treatment Synthetic Data](#3.-Example-Usage-with-Multiple-Treatment-Synthetic-Data)
# 4. [Example Usage with Real Continuous Treatment Observational Data](#4.-Example-Usage-with-Real-Continuous-Treatment-Observational-Data)

# %%
# %load_ext lab_black

# %%
import econml

# %%
# Main imports
from econml.orf import DMLOrthoForest, DROrthoForest
from econml.dml import CausalForestDML
from econml.sklearn_extensions.linear_model import (
    WeightedLassoCVWrapper,
    WeightedLasso,
    WeightedLassoCV,
)

# Helper imports
import numpy as np
from itertools import product
from sklearn.linear_model import (
    Lasso,
    LassoCV,
    LogisticRegression,
    LogisticRegressionCV,
)
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 1. Example Usage with Continuous Treatment Synthetic Data

# %% [markdown]
# ## 1.1 DGP
# We use the data generating process (DGP) from [here](https://arxiv.org/abs/1806.03467). The DGP is described by the following equations:
#
# \begin{align}
# T =& \langle W, \beta\rangle + \eta, & \;\eta \sim \text{Uniform}(-1, 1)\\
# Y =& T\cdot \theta(X) + \langle W, \gamma\rangle + \epsilon, &\; \epsilon \sim \text{Uniform}(-1, 1)\\
# W \sim& \text{Normal}(0,\, I_{n_w})\\
# X \sim& \text{Uniform}(0,1)^{n_x}
# \end{align}
#
# where $W$ is a matrix of high-dimensional confounders and $\beta, \gamma$ have high sparsity.
#
# For this DGP,
# \begin{align}
# \theta(x) = \exp(2\cdot x_1).
# \end{align}

# %%
# Treatment effect function
def exp_te(x):
    return np.exp(2 * x[0])

# %%
# DGP constants
np.random.seed(123)
n = 1000
n_w = 30
support_size = 5
n_x = 1
# Outcome support
support_Y = np.random.choice(range(n_w), size=support_size, replace=False)
coefs_Y = np.random.uniform(0, 1, size=support_size)
epsilon_sample = lambda n: np.random.uniform(-1, 1, size=n)
# Treatment support
support_T = support_Y
coefs_T = np.random.uniform(0, 1, size=support_size)
eta_sample = lambda n: np.random.uniform(-1, 1, size=n)

# Generate controls, covariates, treatments and outcomes
W = np.random.normal(0, 1, size=(n, n_w))
X = np.random.uniform(0, 1, size=(n, n_x))
# Heterogeneous treatment effects
TE = np.array([exp_te(x_i) for x_i in X])
T = np.dot(W[:, support_T], coefs_T) + eta_sample(n)
Y = TE * T + np.dot(W[:, support_Y], coefs_Y) + epsilon_sample(n)

# ORF parameters and test data
subsample_ratio = 0.3
lambda_reg = np.sqrt(np.log(n_w) / (10 * subsample_ratio * n))
X_test = np.array(list(product(np.arange(0, 1, 0.01), repeat=n_x)))

# %% [markdown]
# ## 1.2. Train Estimator
#
# **Note:** The models in the final stage of the estimation (``model_T_final``, ``model_Y_final``) need to support sample weighting.
#
# If the models of choice do not support sample weights (e.g. ``sklearn.linear_model.LassoCV``), the ``econml`` packages provides a convenient wrapper for these models ``WeightedModelWrapper`` in order to allow sample weights.

# %%
est = DMLOrthoForest(
    n_trees=1000,
    min_leaf_size=5,
    max_depth=50,
    subsample_ratio=subsample_ratio,
    model_T=Lasso(alpha=lambda_reg),
    model_Y=Lasso(alpha=lambda_reg),
    model_T_final=WeightedLasso(alpha=lambda_reg),
    model_Y_final=WeightedLasso(alpha=lambda_reg),
    global_residualization=False,
    random_state=123,
)

# %% [markdown]
# To use the built-in confidence intervals constructed via Bootstrap of Little Bags, we can specify `inference="blb"` at `fit` time or leave the default `inference='auto'` which will automatically use the Bootstrap of Little Bags.

# %%
est.fit(Y, T, X=X, W=W, inference="blb")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08869999174824006, tolerance: 0.056233270762378135
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03609108646025591, tolerance: 0.02770564699580279
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04581050402027148, tolerance: 0.037282079839702206
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010528708639127124, tolerance: 0.007668759173188848
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23532482416676012, tolerance: 0.20071791868628722
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    8.6s
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.042982239557616486, tolerance: 0.030634706108734623
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16463726508554544, tolerance: 0.05714904071750944
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.054765444882211856, tolerance: 0.036514722256000456
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006680693871637167, tolerance: 0.0027499948094850263
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016510690657320526, tolerance: 0.00957962703826436
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4882948515181523, tolerance: 0.2313866380463167
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03381415714212044, tolerance: 0.02801192060195631
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024780534077743943, tolerance: 0.021831782908170668
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02037239200850803, tolerance: 0.01464559696984609
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17644911944929087, tolerance: 0.060884270853239775
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005512276111813735, tolerance: 0.001656423155022311
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25969829424274016, tolerance: 0.09472857116908934
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02937372131937585, tolerance: 0.021432123935259697
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021654349160225128, tolerance: 0.016701768049961034
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06484734720248045, tolerance: 0.02561344638424189
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0722418744652662, tolerance: 0.06642332841727301
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00922851178879075, tolerance: 0.006310171435825805
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023578051957677648, tolerance: 0.021246010288801548
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033152007781034026, tolerance: 0.008847030429576007
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02677374803037369, tolerance: 0.006504165109050783
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18099421536724397, tolerance: 0.15579818590930744
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0019825538605097726, tolerance: 0.0016446787794426698
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19833152871351484, tolerance: 0.1790693130325174
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21334880517236768, tolerance: 0.025868846967424277
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12719346231022194, tolerance: 0.10855043350095744
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025568184271959213, tolerance: 0.020170025294374186
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21465807453598929, tolerance: 0.09091298889715618
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03497780218061597, tolerance: 0.028893589172054982
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03824745967295927, tolerance: 0.016401080207670077
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07056854632988119, tolerance: 0.036207792981806125
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01603194044452605, tolerance: 0.011495831348987075
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03936698556767797, tolerance: 0.03364390280007583
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013338188267452755, tolerance: 0.010740645482614818
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.054991288626625265, tolerance: 0.04793007240697142
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010803725146180387, tolerance: 0.008770505450211342
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14857327525660058, tolerance: 0.07819492598216662
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1634711949367016, tolerance: 0.12417744536625035
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06407514449689888, tolerance: 0.023006646116003143
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14229677992371578, tolerance: 0.10227609788024791
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09728314448889691, tolerance: 0.04237958018368687
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10704595854527776, tolerance: 0.07305607730037669
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12222602189233886, tolerance: 0.0582004810854745
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027868958568240343, tolerance: 0.02167265898920731
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0579152820041724, tolerance: 0.050697606774427896
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1399061971076193, tolerance: 0.04243986302183716
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29770620095666156, tolerance: 0.05058857207448101
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13866585344542193, tolerance: 0.07714761090791922
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07654316036659264, tolerance: 0.02148922994127901
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02804287322148502, tolerance: 0.027387346663485006
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2137355953349489, tolerance: 0.07383205544853609
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0325428478617068, tolerance: 0.012831980833819803
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41485440586409084, tolerance: 0.13432150808847484
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17726935709790165, tolerance: 0.0794463324844976
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0027301318829217602, tolerance: 0.002056478296102839
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0526113516542461, tolerance: 0.03999748726264384
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1706040694749984, tolerance: 0.07703945910475882
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  1.1min finished

# %%
# Calculate treatment effects
treatment_effects = est.effect(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   22.6s finished

# %%
# Calculate default (95%) confidence intervals for the test data
te_lower, te_upper = est.effect_interval(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   17.8s finished

# %%
res = est.effect_inference(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   14.1s finished

# %%
res.summary_frame().head()
# Out:
#    point_estimate  stderr  zstat  pvalue  ci_lower  ci_upper
# X
# 0           1.161   0.183  6.339     0.0     0.802     1.520
# 1           1.171   0.177  6.628     0.0     0.825     1.518
# 2           1.182   0.171  6.925     0.0     0.847     1.516
# 3           1.192   0.165  7.228     0.0     0.869     1.515
# 4           1.202   0.160  7.533     0.0     0.890     1.515

# %%
res.population_summary()
# Out:
# <table class="simpletable">
# <caption>Uncertainty of Mean Point Estimate</caption>
# <tr>
#   <th>mean_point</th> <th>stderr_mean</th> <th>zstat</th> <th>pvalue</th> <th>ci_mean_lower</th> <th>ci_mean_upper</th>
# </tr>
# <tr>
#      <td>3.179</td>      <td>0.287</td>    <td>11.06</td>   <td>0.0</td>      <td>2.616</td>         <td>3.742</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Distribution of Point Estimate</caption>
# <tr>
#   <th>std_point</th> <th>pct_point_lower</th> <th>pct_point_upper</th>
# </tr>
# <tr>
#     <td>1.715</td>        <td>1.187</td>           <td>6.276</td>
# </tr>
# </table>
# <table class="simpletable">
# <caption>Total Variance of Point Estimate</caption>
# <tr>
#   <th>stderr_point</th> <th>ci_point_lower</th> <th>ci_point_upper</th>
# </tr>
# <tr>
#       <td>1.739</td>         <td>1.079</td>          <td>6.525</td>
# </tr>
# </table><br/><br/>Note: The stderr_mean is a conservative upper bound.

# %% [markdown]
# Similarly we can estimate effects and get confidence intervals and inference results using a `CausalForest`.

# %%
est2 = CausalForestDML(
    model_t=Lasso(alpha=lambda_reg),
    model_y=Lasso(alpha=lambda_reg),
    n_estimators=4000,
    min_samples_leaf=5,
    max_depth=50,
    verbose=0,
    random_state=123,
)
est2.tune(Y, T, X=X, W=W)
est2.fit(Y, T, X=X, W=W)
treatment_effects2 = est2.effect(X_test)
te_lower2, te_upper2 = est2.effect_interval(X_test, alpha=0.01)

# %% [markdown]
# ## 1.3. Performance Visualization

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title("ContinuousOrthoForest")
plt.plot(X_test, treatment_effects, label="ORF estimate")
expected_te = np.array([exp_te(x_i) for x_i in X_test])
plt.plot(X_test[:, 0], expected_te, "b--", label="True effect")
plt.fill_between(X_test[:, 0], te_lower, te_upper, label="95% BLB CI", alpha=0.3)
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.subplot(1, 2, 2)
plt.title("CausalForest")
plt.plot(X_test, treatment_effects2, label="ORF estimate")
expected_te = np.array([exp_te(x_i) for x_i in X_test])
plt.plot(X_test[:, 0], expected_te, "b--", label="True effect")
plt.fill_between(X_test[:, 0], te_lower2, te_upper2, label="95% BLB CI", alpha=0.3)
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.show()

# %% [markdown]
# # 2. Example Usage with Binary Treatment Synthetic Data

# %% [markdown]
# ## 2.1. DGP
# We use the following DGP:
#
# \begin{align}
# T \sim & \text{Bernoulli}\left(f(W)\right), &\; f(W)=\sigma(\langle W, \beta\rangle + \eta), \;\eta \sim \text{Uniform}(-1, 1)\\
# Y = & T\cdot \theta(X) + \langle W, \gamma\rangle + \epsilon, & \; \epsilon \sim \text{Uniform}(-1, 1)\\
# W \sim & \text{Normal}(0,\, I_{n_w}) & \\
# X \sim & \text{Uniform}(0,\, 1)^{n_x}
# \end{align}
#
# where $W$ is a matrix of high-dimensional confounders, $\beta, \gamma$ have high sparsity and $\sigma$ is the sigmoid function.
#
# For this DGP,
# \begin{align}
# \theta(x) = \exp( 2\cdot x_1 ).
# \end{align}

# %%
# DGP constants
np.random.seed(1234)
n = 1000
n_w = 30
support_size = 5
n_x = 1
# Outcome support
support_Y = np.random.choice(range(n_w), size=support_size, replace=False)
coefs_Y = np.random.uniform(0, 1, size=support_size)
epsilon_sample = lambda n: np.random.uniform(-1, 1, size=n)
# Treatment support
support_T = support_Y
coefs_T = np.random.uniform(0, 1, size=support_size)
eta_sample = lambda n: np.random.uniform(-1, 1, size=n)

# Generate controls, covariates, treatments and outcomes
W = np.random.normal(0, 1, size=(n, n_w))
X = np.random.uniform(0, 1, size=(n, n_x))
# Heterogeneous treatment effects
TE = np.array([exp_te(x_i) for x_i in X])
# Define treatment
log_odds = np.dot(W[:, support_T], coefs_T) + eta_sample(n)
T_sigmoid = 1 / (1 + np.exp(-log_odds))
T = np.array([np.random.binomial(1, p) for p in T_sigmoid])
# Define the outcome
Y = TE * T + np.dot(W[:, support_Y], coefs_Y) + epsilon_sample(n)

# ORF parameters and test data
subsample_ratio = 0.4
X_test = np.array(list(product(np.arange(0, 1, 0.01), repeat=n_x)))

# %% [markdown]
# ## 2.2. Train Estimator

# %%
est = DROrthoForest(
    n_trees=200,
    min_leaf_size=10,
    max_depth=30,
    subsample_ratio=subsample_ratio,
    propensity_model=LogisticRegression(
        C=1 / (X.shape[0] * lambda_reg), penalty="l1", solver="saga"
    ),
    model_Y=Lasso(alpha=lambda_reg),
    propensity_model_final=LogisticRegression(
        C=1 / (X.shape[0] * lambda_reg), penalty="l1", solver="saga"
    ),
    model_Y_final=WeightedLasso(alpha=lambda_reg),
)

# %%
est.fit(Y, T, X=X, W=W)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   12.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    3.8s finished

# %%
# Calculate treatment effects for the default treatment points T0=0 and T1=1
treatment_effects = est.effect(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   11.3s finished

# %%
# Calculate default (95%) confidence intervals for the default treatment points T0=0 and T1=1
te_lower, te_upper = est.effect_interval(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.6s finished

# %%
est2 = CausalForestDML(
    model_y=Lasso(alpha=lambda_reg),
    model_t=LogisticRegression(C=1 / (X.shape[0] * lambda_reg)),
    n_estimators=200,
    min_samples_leaf=5,
    max_depth=50,
    max_samples=subsample_ratio / 2,
    discrete_treatment=True,
    random_state=123,
)
est2.fit(Y, T, X=X, W=W, cache_values=True)
treatment_effects2 = est2.effect(X_test)
te_lower2, te_upper2 = est2.effect_interval(X_test)

# %%
est2.summary()
# Out:
# Population summary of CATE predictions on Training Data
# <class 'econml.utilities.Summary'>
# """
#                Uncertainty of Mean Point Estimate
# ================================================================
# mean_point stderr_mean zstat  pvalue ci_mean_lower ci_mean_upper
# ----------------------------------------------------------------
#      3.088       0.157 19.677    0.0          2.78         3.396
#       Distribution of Point Estimate
# =========================================
# std_point pct_point_lower pct_point_upper
# -----------------------------------------
#     1.757           0.846           6.962
#      Total Variance of Point Estimate
# ==========================================
# stderr_point ci_point_lower ci_point_upper
# ------------------------------------------
#        1.764          0.774          6.951
#         Doubly Robust ATE on Training Data Results
# =========================================================
#     point_estimate stderr zstat  pvalue ci_lower ci_upper
# ---------------------------------------------------------
# ATE          3.158  0.082 38.551    0.0    2.997    3.318
#      Doubly Robust ATT(T=0) on Training Data Results
# =========================================================
#     point_estimate stderr zstat  pvalue ci_lower ci_upper
# ---------------------------------------------------------
# ATT            3.1  0.096 32.322    0.0    2.912    3.288
#      Doubly Robust ATT(T=1) on Training Data Results
# =========================================================
#     point_estimate stderr zstat  pvalue ci_lower ci_upper
# ---------------------------------------------------------
# ATT          3.218  0.134 23.965    0.0    2.955    3.481
# ---------------------------------------------------------
#
# Note: The stderr_mean is a conservative upper bound.
# """

# %% [markdown]
# ## 2.3. Performance Visualization

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title("DiscreteTreatmentOrthoForest")
plt.plot(X_test, treatment_effects, label="ORF estimate")
expected_te = np.array([exp_te(x_i) for x_i in X_test])
plt.plot(X_test[:, 0], expected_te, "b--", label="True effect")
plt.fill_between(X_test[:, 0], te_lower, te_upper, label="95% BLB CI", alpha=0.3)
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.subplot(1, 2, 2)
plt.title("CausalForest")
plt.plot(X_test, treatment_effects2, label="ORF estimate")
expected_te = np.array([exp_te(x_i) for x_i in X_test])
plt.plot(X_test[:, 0], expected_te, "b--", label="True effect")
plt.fill_between(X_test[:, 0], te_lower2, te_upper2, label="95% BLB CI", alpha=0.3)
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.show()

# %% [markdown]
# # 3. Example Usage with Multiple Treatment Synthetic Data

# %% [markdown]
# ## 3.1. DGP
# We use the following DGP:
#
# \begin{align}
# Y = & \sum_{t=1}^{n_{\text{treatments}}} 1\{T=t\}\cdot \theta_{T}(X) + \langle W, \gamma\rangle + \epsilon, \; \epsilon \sim \text{Unif}(-1, 1), \\
# \text{Pr}[T=t \mid W] \propto & \exp\{\langle W, \beta_t \rangle\}, \;\;\;\; \forall t\in \{0, 1, \ldots, n_{\text{treatments}}\}
# \end{align}
#
# where $W$ is a matrix of high-dimensional confounders, $\beta_t, \gamma$ are sparse.
#
# For this particular example DGP we used $n_{\text{treatments}}=3$ and
# \begin{align}
# \theta_1(x) = & \exp( 2 x_1 ),\\
# \theta_2(x) = &  3 \cdot \sigma(100\cdot (x_1 - .5)),\\
# \theta_3(x) = & -2 \cdot \sigma(100\cdot (x_1 - .25)),
# \end{align}
# where $\sigma$ is the sigmoid function.

# %%
def get_test_train_data(n, n_w, support_size, n_x, te_func, n_treatments):
    # Outcome support
    support_Y = np.random.choice(range(n_w), size=support_size, replace=False)
    coefs_Y = np.random.uniform(0, 1, size=support_size)
    epsilon_sample = lambda n: np.random.uniform(-1, 1, size=n)
    # Treatment support
    support_T = support_Y
    coefs_T = np.random.uniform(0, 1, size=(support_size, n_treatments))
    eta_sample = lambda n: np.random.uniform(-1, 1, size=n)
    # Generate controls, covariates, treatments and outcomes
    W = np.random.normal(0, 1, size=(n, n_w))
    X = np.random.uniform(0, 1, size=(n, n_x))
    # Heterogeneous treatment effects
    TE = np.array([te_func(x_i, n_treatments) for x_i in X])
    log_odds = np.dot(W[:, support_T], coefs_T)
    T_sigmoid = np.exp(log_odds)
    T_sigmoid = T_sigmoid / np.sum(T_sigmoid, axis=1, keepdims=True)
    T = np.array([np.random.choice(n_treatments, p=p) for p in T_sigmoid])
    TE = np.concatenate((np.zeros((n, 1)), TE), axis=1)
    Y = TE[np.arange(n), T] + np.dot(W[:, support_Y], coefs_Y) + epsilon_sample(n)
    X_test = np.array(list(product(np.arange(0, 1, 0.01), repeat=n_x)))

    return (Y, T, X, W), (X_test, np.array([te_func(x, n_treatments) for x in X_test]))

# %%
import scipy.special


def te_func(x, n_treatments):
    return [
        np.exp(2 * x[0]),
        3 * scipy.special.expit(100 * (x[0] - 0.5)) - 1,
        -2 * scipy.special.expit(100 * (x[0] - 0.25)),
    ]


np.random.seed(123)
(Y, T, X, W), (X_test, te_test) = get_test_train_data(2000, 3, 3, 1, te_func, 4)

# %% [markdown]
# ## 3.2. Train Estimator

# %%
est = DROrthoForest(n_trees=500, model_Y=WeightedLasso(alpha=lambda_reg))

# %%
est.fit(Y, T, X=X, W=W)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   12.3s
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   20.7s
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:   34.0s
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done 497 out of 500 | elapsed:   46.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   46.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    2.7s
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:   12.3s
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   26.4s finished

# %%
# Calculate marginal treatment effects
treatment_effects = est.const_marginal_effect(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    7.5s finished

# %%
# Calculate default (95%) marginal confidence intervals for the test data
te_lower, te_upper = est.const_marginal_effect_interval(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    4.0s finished

# %%
res = est.const_marginal_effect_inference(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    4.1s finished

# %%
res.summary_frame()
# Out:
#          point_estimate  stderr   zstat  pvalue  ci_lower  ci_upper
# X  T
# 0  T0_1           1.016   0.157   6.469   0.000     0.708     1.323
#    T0_2          -0.987   0.149  -6.620   0.000    -1.279    -0.695
#    T0_3           0.036   0.224   0.159   0.874    -0.403     0.474
# 1  T0_1           1.020   0.156   6.543   0.000     0.715     1.326
#    T0_2          -0.987   0.148  -6.676   0.000    -1.277    -0.697
# ...                 ...     ...     ...     ...       ...       ...
# 98 T0_2           1.970   0.208   9.455   0.000     1.562     2.378
#    T0_3          -2.022   0.163 -12.407   0.000    -2.341    -1.702
# 99 T0_1           6.869   0.248  27.743   0.000     6.384     7.354
#    T0_2           1.964   0.209   9.400   0.000     1.554     2.373
#    T0_3          -2.022   0.166 -12.213   0.000    -2.347    -1.698
#
# [300 rows x 6 columns]

# %%
est2 = CausalForestDML(
    model_y=Lasso(alpha=lambda_reg),
    model_t=LogisticRegression(C=1 / (X.shape[0] * lambda_reg)),
    n_estimators=4000,
    min_samples_leaf=5,
    max_depth=50,
    max_samples=subsample_ratio / 2,
    discrete_treatment=True,
    random_state=123,
)
est2.fit(Y, T, X=X, W=W)
treatment_effects2 = est2.const_marginal_effect(X_test)
te_lower2, te_upper2 = est2.const_marginal_effect_interval(X_test, alpha=0.01)

# %% [markdown]
# ## 3.3. Performance Visualization

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title("DiscreteTreatmentOrthoForest")
y = treatment_effects
colors = ["b", "r", "g"]
for it in range(y.shape[1]):
    plt.plot(
        X_test[:, 0],
        te_test[:, it],
        "--",
        label="True effect T={}".format(it),
        color=colors[it],
    )
    plt.fill_between(
        X_test[:, 0],
        te_lower[:, it],
        te_upper[:, it],
        alpha=0.3,
        color="C{}".format(it),
    )
    plt.plot(
        X_test, y[:, it], label="ORF estimate T={}".format(it), color="C{}".format(it)
    )
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.subplot(1, 2, 2)
plt.title("CausalForest")
y = treatment_effects2
colors = ["b", "r", "g"]
for it in range(y.shape[1]):
    plt.plot(
        X_test[:, 0],
        te_test[:, it],
        "--",
        label="True effect T={}".format(it),
        color=colors[it],
    )
    plt.fill_between(
        X_test[:, 0],
        te_lower2[:, it],
        te_upper2[:, it],
        alpha=0.3,
        color="C{}".format(it),
    )
    plt.plot(
        X_test, y[:, it], label="ORF estimate T={}".format(it), color="C{}".format(it)
    )
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.show()

# %% [markdown]
# # 4. Example Usage with Real Continuous Treatment Observational Data
#
# We applied our technique to Dominick’s dataset, a popular historical dataset of store-level orange juice prices and sales provided by University of Chicago Booth School of Business.
#
# The dataset is comprised of a large number of covariates $W$, but researchers might only be interested in learning the elasticity of demand as a function of a few variables $x$ such
# as income or education.
#
# We applied the `ContinuousTreatmentOrthoForest` to estimate orange juice price elasticity
# as a function of income, and our results, unveil the natural phenomenon that lower income consumers are more price-sensitive.

# %% [markdown]
# ## 4.1. Data

# %%
# A few more imports
import os
import pandas as pd
import urllib.request
from sklearn.preprocessing import StandardScaler

# %%
# Import the data
file_name = "oj_large.csv"

if not os.path.isfile(file_name):
    print("Downloading file (this might take a few seconds)...")
    urllib.request.urlretrieve(
        "https://msalicedatapublic.blob.core.windows.net/datasets/OrangeJuice/oj_large.csv",
        file_name,
    )
oj_data = pd.read_csv(file_name)
oj_data.head()
# Out:
# Downloading file (this might take a few seconds)...
#    store      brand  week   logmove  feat  price     AGE60      EDUC   ETHNIC  \
# 0      2  tropicana    40  9.018695     0   3.87  0.232865  0.248935  0.11428
# 1      2  tropicana    46  8.723231     0   3.87  0.232865  0.248935  0.11428
# 2      2  tropicana    47  8.253228     0   3.87  0.232865  0.248935  0.11428
# 3      2  tropicana    48  8.987197     0   3.87  0.232865  0.248935  0.11428
# 4      2  tropicana    50  9.093357     0   3.87  0.232865  0.248935  0.11428
#
#       INCOME   HHLARGE   WORKWOM   HVAL150  SSTRDIST   SSTRVOL  CPDIST5  \
# 0  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 1  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 2  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 3  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
# 4  10.553205  0.103953  0.303585  0.463887  2.110122  1.142857  1.92728
#
#     CPWVOL5
# 0  0.376927
# 1  0.376927
# 2  0.376927
# 3  0.376927
# 4  0.376927

# %%
# Prepare data
Y = oj_data["logmove"].values
T = np.log(oj_data["price"]).values
scaler = StandardScaler()
W1 = scaler.fit_transform(
    oj_data[
        [
            c
            for c in oj_data.columns
            if c not in ["price", "logmove", "brand", "week", "store"]
        ]
    ].values
)
W2 = pd.get_dummies(oj_data[["brand"]]).values
W = np.concatenate([W1, W2], axis=1)
X = oj_data[["INCOME"]].values

# %% [markdown]
# ## 4.2. Train Estimator

# %%
# Define some parameters
n_trees = 1000
min_leaf_size = 50
max_depth = 20
subsample_ratio = 0.04

# %%
est = DMLOrthoForest(
    n_trees=n_trees,
    min_leaf_size=min_leaf_size,
    max_depth=max_depth,
    subsample_ratio=subsample_ratio,
    model_T=Lasso(alpha=0.1),
    model_Y=Lasso(alpha=0.1),
    model_T_final=WeightedLassoCVWrapper(cv=3),
    model_Y_final=WeightedLassoCVWrapper(cv=3),
)

# %%
est.fit(Y, T, X=X, W=W)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:    8.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:    3.5s finished

# %%
min_income = 10.0
max_income = 11.1
delta = (max_income - min_income) / 100
X_test = np.arange(min_income, max_income + delta - 0.001, delta).reshape(-1, 1)

# %%
# Calculate marginal treatment effects
treatment_effects = est.const_marginal_effect(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 101 out of 101 | elapsed:   45.8s finished

# %%
# Calculate default (95%) marginal confidence intervals for the test data
te_upper, te_lower = est.const_marginal_effect_interval(X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 101 out of 101 | elapsed:   40.5s finished

# %%
est2 = CausalForestDML(
    model_y=WeightedLassoCVWrapper(cv=3),
    model_t=WeightedLassoCVWrapper(cv=3),
    n_estimators=n_trees,
    min_samples_leaf=min_leaf_size,
    max_depth=max_depth,
    max_samples=subsample_ratio / 2,
    random_state=123,
)
est2.fit(Y, T, X=X, W=W)
treatment_effects2 = est2.effect(X_test)
te_lower2, te_upper2 = est2.effect_interval(X_test)

# %% [markdown]
# ## 4.3. Performance Visualization

# %%
# Plot Orange Juice elasticity as a function of income
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(X_test.flatten(), treatment_effects, label="OJ Elasticity")
plt.fill_between(X_test.flatten(), te_lower, te_upper, label="95% BLB CI", alpha=0.3)
plt.xlabel(r"$\log$(Income)")
plt.ylabel("Orange Juice Elasticity")
plt.legend()
plt.title("Orange Juice Elasticity vs Income: ContinuousTreatmentOrthoForest")
plt.subplot(1, 2, 2)
plt.plot(X_test.flatten(), treatment_effects2, label="OJ Elasticity")
plt.fill_between(X_test.flatten(), te_lower2, te_upper2, label="95% BLB CI", alpha=0.3)
plt.xlabel(r"$\log$(Income)")
plt.ylabel("Orange Juice Elasticity")
plt.legend()
plt.title("Orange Juice Elasticity vs Income: CausalForest")
plt.show()
