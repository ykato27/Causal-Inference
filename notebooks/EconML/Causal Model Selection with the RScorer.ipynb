# %% [markdown]
# <table border="0">
#     <tr>
#         <td>
#             <img src="https://ictd2016.files.wordpress.com/2016/04/microsoft-research-logo-copy.jpg" style="width 30px;" />
#              </td>
#         <td>
#             <img src="https://www.microsoft.com/en-us/research/wp-content/uploads/2016/12/MSR-ALICE-HeaderGraphic-1920x720_1-800x550.jpg" style="width 100px;"/></td>
#         </tr>
# </table>

# %% [markdown]
# # Model Selection for Causal Effect Model with the RScorer

# %%
# %load_ext lab_black

# %%
import econml

# %%
## Ignore warnings
import warnings

warnings.filterwarnings("ignore")

# %%
# Main imports
from econml.dml import DML, LinearDML, SparseLinearDML, NonParamDML
from econml.metalearners import XLearner, TLearner, SLearner, DomainAdaptationLearner
from econml.dr import DRLearner

import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LassoCV
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ## 2. Example Usage with Single Binary Treatment Synthetic Data

# %% [markdown]
# ### 2.1. DGP
# We use the following DGP:
#
# \begin{align}
# T \sim & \text{Bernoulli}\left(f(W)\right), &\; f(W)=\sigma(\langle W, \beta\rangle + \eta), \;\eta \sim \text{Uniform}(-1, 1)\\
# Y = & T\cdot \theta(X) + \langle W, \gamma\rangle + \epsilon, & \; \epsilon \sim \text{Uniform}(-1, 1)\\
# W \sim & \text{Normal}(0,\, I_{n_w}) & \\
# X \sim & \text{Uniform}(0,\, 1)^{n_x}
# \end{align}
#
# where $W$ is a matrix of high-dimensional confounders, $\beta, \gamma$ have high sparsity and $\sigma$ is the sigmoid function.
#
# For this DGP,
# \begin{align}
# \theta(x) = 1\{x_0 > .5\}
# \end{align}

# %%
# Treatment effect function
def exp_te(x):
    return x[:, 0] > 0.5


np.random.seed(123)
n = 5000
support_size = 5
n_x = 10
# Outcome support
support_Y = np.random.choice(range(n_x), size=support_size, replace=False)
coefs_Y = np.random.uniform(0, 1, size=support_size)
epsilon_sample = lambda n: np.random.uniform(-1, 1, size=n)
# Treatment support
support_T = support_Y
coefs_T = np.random.uniform(0, 1, size=support_size)
eta_sample = lambda n: np.random.uniform(-1, 1, size=n)

# Generate controls, covariates, treatments and outcomes
X = np.random.uniform(0, 1, size=(n, n_x))
# Heterogeneous treatment effects
TE = exp_te(X)
# Define treatment
log_odds = np.dot(X[:, support_T], coefs_T) + eta_sample(n)
T_sigmoid = 1 / (1 + np.exp(-log_odds))
T = np.array([np.random.binomial(1, p) for p in T_sigmoid])
# Define the outcome
Y = TE * T + np.dot(X[:, support_Y], coefs_Y) + epsilon_sample(n)

# get testing data
X_test = np.random.uniform(0, 1, size=(n, n_x))
X_test[:, 0] = np.linspace(0, 1, n)
expected_te_test = exp_te(X_test)

# %% [markdown]
# ### 2.2. Train Estimator

# %%
reg = lambda: RandomForestRegressor(min_samples_leaf=10)
clf = lambda: RandomForestClassifier(min_samples_leaf=10)

# %%
X_train, X_val, T_train, T_val, Y_train, Y_val = train_test_split(
    X, T, Y, test_size=0.4
)

# %%
models = [
    (
        "ldml",
        LinearDML(
            model_y=reg(),
            model_t=clf(),
            discrete_treatment=True,
            linear_first_stages=False,
            cv=3,
        ),
    ),
    (
        "sldml",
        SparseLinearDML(
            model_y=reg(),
            model_t=clf(),
            discrete_treatment=True,
            featurizer=PolynomialFeatures(degree=2, include_bias=False),
            linear_first_stages=False,
            cv=3,
        ),
    ),
    ("xlearner", XLearner(models=reg(), cate_models=reg(), propensity_model=clf())),
    (
        "dalearner",
        DomainAdaptationLearner(
            models=reg(), final_models=reg(), propensity_model=clf()
        ),
    ),
    ("slearner", SLearner(overall_model=reg())),
    ("tlearner", TLearner(models=reg())),
    (
        "drlearner",
        DRLearner(
            model_propensity=clf(), model_regression=reg(), model_final=reg(), cv=3
        ),
    ),
    (
        "rlearner",
        NonParamDML(
            model_y=reg(),
            model_t=clf(),
            model_final=reg(),
            discrete_treatment=True,
            cv=3,
        ),
    ),
    (
        "dml3dlasso",
        DML(
            model_y=reg(),
            model_t=clf(),
            model_final=LassoCV(),
            discrete_treatment=True,
            featurizer=PolynomialFeatures(degree=3),
            linear_first_stages=False,
            cv=3,
        ),
    ),
]

# %%
from joblib import Parallel, delayed


def fit_model(name, model):
    return name, model.fit(Y_train, T_train, X=X_train)


models = Parallel(n_jobs=-1, verbose=1)(
    delayed(fit_model)(name, mdl) for name, mdl in models
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22571593592772388, tolerance: 0.10705492659955833
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.24834407683283644, tolerance: 0.10705492659955833
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16624234562391393, tolerance: 0.10705492659955833
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15864871991993823, tolerance: 0.10705492659955833
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19784552129158328, tolerance: 0.10705492659955833
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3931302346109078, tolerance: 0.1073620946089297
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2422177068253859, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2290757975647466, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.34761122777081255, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7065552749330664, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5898068966610026, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5947384173740602, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6095208915448893, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5944385187418675, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5901236344817562, tolerance: 0.10791089492032935
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1965525773753969, tolerance: 0.037942911205674855
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18344250243766314, tolerance: 0.037942911205674855
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09939317797111014, tolerance: 0.037942911205674855
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15098530616539652, tolerance: 0.03699485073101604
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1504032300590974, tolerance: 0.03699485073101604
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0751185546051083, tolerance: 0.03699485073101604
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14114573644960604, tolerance: 0.035506132654713536
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19179443954464137, tolerance: 0.035506132654713536
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08491805515907225, tolerance: 0.035506132654713536
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.006847083764169, tolerance: 0.0552219472957022
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7456806486994765, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.292873350243326, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5377375374180247, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6561584787766606, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3145097959572922, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3196808905986472, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2593462314135877, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.251401801937277, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3103980826915631, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9175499539740031, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6668317450287304, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3607761785939374, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.408960479020152, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3529662193892591, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33769626388846063, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.36040024271301263, tolerance: 0.10839900444800046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6966172350134912, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3844168415677132, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3717137461144375, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.936857209062282, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.153245174843505, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8759536186724972, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.611212032720232, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.732853393770483, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.661323456776017, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.129404312061752, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.977201722128711, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.20429734113577, tolerance: 0.11059920857202545
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.30015660017693335, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7502427600619512, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9097793904466016, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9469284885335583, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.801151537238411, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3099773442090736, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2509301337275929, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8277873974250269, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35582834796593943, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20037573772287942, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1540006812218735, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2706601855085182, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19188311543837244, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3021414550028112, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3475485923954693, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5330515574007677, tolerance: 0.10911373204543412
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4626768689079199, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6953297951297372, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.758706249592592, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7522710785838171, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9143046297873525, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2717746885533643, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2749060606355442, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1542487386134326, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8367975164302379, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7083663450487165, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6342327256985527, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0187739199741372, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.5497303650486174, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.483365202519394, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.57007826398285, tolerance: 0.10879884933919726
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2785922914886214, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6384265701490222, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7906538488202841, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8466448573582284, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8680500508201021, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9575724078449639, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0285899084451557, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9847643589683912, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11969285436498467, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18069004852281978, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10975475820191605, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3553778551170126, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.35430536785986533, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33945480158479313, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5217812183798287, tolerance: 0.10877453742297404
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27471154040210877, tolerance: 0.10877453742297404
# The final model has a nonzero intercept for at least one outcome; it will be subtracted, but consider fitting a model without an intercept if possible.
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:  2.3min finished

# %%
from econml.score import RScorer

scorer = RScorer(
    model_y=reg(),
    model_t=clf(),
    discrete_treatment=True,
    cv=3,
    mc_iters=3,
    mc_agg="median",
)
scorer.fit(Y_val, T_val, X=X_val)

# %%
rscore = [scorer.score(mdl) for _, mdl in models]

# %%
expected_te_val = exp_te(X_val)

# %%
rootpehe = [
    np.sqrt(np.mean((expected_te_val.flatten() - mdl.effect(X_val).flatten()) ** 2))
    for _, mdl in models
]

# %%
plt.scatter(rootpehe, rscore)
plt.xlabel("rpehe")
plt.ylabel("rscore")
plt.show()

# %% [markdown]
# ### 2.3. Performance Visualization

# %%
plt.figure(figsize=(16, 16))
rows = int(np.ceil(len(models) / 3))
for it, (name, mdl) in enumerate(models):
    plt.subplot(rows, 3, it + 1)
    plt.title(
        "{}. RScore: {:.3f}, Root-PEHE: {:.3f}".format(name, rscore[it], rootpehe[it])
    )
    plt.plot(X_test[:, 0], mdl.effect(X_test), label="{}".format(name))
    plt.plot(X_test[:, 0], expected_te_test, "b--", label="True effect")
    plt.ylabel("Treatment Effect")
    plt.xlabel("x")
    plt.legend()
plt.show()

# %% [markdown]
# # Getting the Best Model

# %%
mdl, score = scorer.best_model([mdl for _, mdl in models])
rootpehe_best = np.sqrt(
    np.mean((expected_te_val.flatten() - mdl.effect(X_val).flatten()) ** 2)
)
plt.figure()
plt.title("RScore: {:.3f}, Root-PEHE: {:.3f}".format(score, rootpehe_best))
plt.plot(X_test[:, 0], mdl.effect(X_test), label="best")
plt.plot(X_test[:, 0], expected_te_test, "b--", label="True effect")
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.show()

# %% [markdown]
# # Getting an Ensemble based on Scores

# %%
mdl, score = scorer.ensemble([mdl for _, mdl in models])
rootpehe_ensemble = np.sqrt(
    np.mean((expected_te_val.flatten() - mdl.effect(X_val).flatten()) ** 2)
)
plt.figure()
plt.title("RScore: {:.3f}, Root-PEHE: {:.3f}".format(score, rootpehe_ensemble))
plt.plot(X_test[:, 0], mdl.effect(X_test), label="ensemble")
plt.plot(X_test[:, 0], expected_te_test, "b--", label="True effect")
plt.ylabel("Treatment Effect")
plt.xlabel("x")
plt.legend()
plt.show()

# %% [markdown]
# # Semi-Synthetic Data

# %%
reg = lambda: RandomForestRegressor(min_samples_leaf=10, random_state=123)
clf = lambda: RandomForestClassifier(min_samples_leaf=10, random_state=123)

# %%
from econml.data.dgps import ihdp_surface_B, ihdp_surface_A

Y, T, X, expected_te = ihdp_surface_B(random_state=123)

# %%
(
    X_train,
    X_val,
    T_train,
    T_val,
    Y_train,
    Y_val,
    expected_te_train,
    expected_te_val,
) = train_test_split(X, T, Y, expected_te, test_size=0.3, random_state=123)

# %%
models = [
    (
        "ldml",
        LinearDML(
            model_y=reg(),
            model_t=clf(),
            discrete_treatment=True,
            linear_first_stages=False,
            cv=3,
        ),
    ),
    ("xlearner", XLearner(models=reg(), cate_models=reg(), propensity_model=clf())),
    (
        "dalearner",
        DomainAdaptationLearner(
            models=reg(), final_models=reg(), propensity_model=clf()
        ),
    ),
    ("slearner", SLearner(overall_model=reg())),
    ("tlearner", TLearner(models=reg())),
    (
        "drlearner",
        DRLearner(
            model_propensity=clf(), model_regression=reg(), model_final=reg(), cv=3
        ),
    ),
    (
        "rlearner",
        NonParamDML(
            model_y=reg(),
            model_t=clf(),
            model_final=reg(),
            discrete_treatment=True,
            cv=3,
        ),
    ),
    (
        "dml3dlasso",
        DML(
            model_y=reg(),
            model_t=clf(),
            model_final=LassoCV(),
            discrete_treatment=True,
            featurizer=PolynomialFeatures(
                degree=2, interaction_only=True, include_bias=False
            ),
            linear_first_stages=False,
            cv=3,
        ),
    ),
]

# %%
from joblib import Parallel, delayed


def fit_model(name, model):
    print("Training: ", name)
    model.fit(Y_train, T_train, X=X_train)
    print("Done training: ", name)
    return name, model


models = Parallel(n_jobs=-1, verbose=1)(
    delayed(fit_model)(name, mdl) for name, mdl in models
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Co-variance matrix is underdetermined. Inference will be invalid!
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3189555796934087, tolerance: 0.19278632614541477
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3505420792151881, tolerance: 0.19278632614541477
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19984009161612448, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4240667145357975, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5905985263791536, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3126826014405424, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23581312151520706, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.42453152043071896, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.992420281491377, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9784417790252746, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.042377079377843, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2388649991925718, tolerance: 0.1887640600879946
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.343266232296628, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32316940675150363, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22822919314808132, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4200268698699574, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.367516351706513, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33865411715066784, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8974182122350385, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5487335823294757, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9312304389546853, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4422729871489537, tolerance: 0.1981443490253977
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.25483893046202866, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23127800525674047, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2008625877870145, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.28765388280135085, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.41362850748805613, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.485422482787385, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5806223850570404, tolerance: 0.19607928268216537
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26621941169344154, tolerance: 0.19235793177778407
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.36400305657878107, tolerance: 0.19235793177778407
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.44887169732669463, tolerance: 0.19235793177778407
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7775452324976868, tolerance: 0.19235793177778407
# The final model has a nonzero intercept for at least one outcome; it will be subtracted, but consider fitting a model without an intercept if possible.
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:   22.2s finished

# %%
from econml.score import RScorer

scorer = RScorer(
    model_y=reg(),
    model_t=clf(),
    discrete_treatment=True,
    cv=3,
    mc_iters=3,
    mc_agg="median",
)
scorer.fit(Y_val, T_val, X=X_val)

# %%
rscore = [scorer.score(mdl) for _, mdl in models]

# %%
rootpehe = [
    np.sqrt(np.mean((expected_te.flatten() - mdl.effect(X).flatten()) ** 2))
    for _, mdl in models
]

# %%
plt.scatter(rootpehe, rscore)
plt.xlabel("rpehe")
plt.ylabel("rscore")
plt.show()

# %%
best, score = scorer.best_model([mdl for _, mdl in models])
rootpehe_best = np.sqrt(
    np.nanmean((expected_te_val.flatten() - best.effect(X_val).flatten()) ** 2)
)
rootpehe_best
# Out:
# 0.739391795258807

# %%
ensemble, score = scorer.ensemble([mdl for _, mdl in models])
rootpehe_ensemble = np.sqrt(
    np.nanmean((expected_te_val.flatten() - ensemble.effect(X_val).flatten()) ** 2)
)
rootpehe_ensemble
# Out:
# 0.7345053783619833

# %%
# Visualization of bias distribution
plt.figure(figsize=(15, 5))
plt.violinplot(
    [np.abs(mdl.effect(X).flatten() - expected_te) for _, mdl in models]
    + [np.abs(best.effect(X).flatten() - expected_te)]
    + [np.abs(ensemble.effect(X).flatten() - expected_te)],
    showmeans=True,
)
plt.ylabel("Bias distribution")
plt.xticks(
    np.arange(1, len(models) + 3), [name for name, _ in models] + ["best", "ensemble"]
)
plt.show()
# Out:
# Training:  ldml
# Done training:  ldml
# Training:  slearner
# Done training:  slearner
# Training:  tlearner
# Done training:  tlearner
# Training:  rlearner
# Done training:  rlearner
# Training:  xlearner
# Done training:  xlearner
# Training:  dalearner
# Done training:  dalearner
# Training:  drlearner
# Done training:  drlearner
# Training:  dml3dlasso
# Done training:  dml3dlasso
